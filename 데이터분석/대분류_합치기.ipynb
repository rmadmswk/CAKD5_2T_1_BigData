# %%
import pandas as pd
import numpy as np
import csv

# %%
t = pd.read_csv('편의선매대분류16.csv',encoding='cp949')

# %%
t1 = pd.read_csv('편의선매대분류17.csv',encoding='cp949')

# %%
t2 = pd.read_csv('전문기타대분류16.csv',encoding='cp949')

# %%
t3 = pd.read_csv('전문기타대분류17.csv',encoding='cp949')

# %%
q = pd.merge(t, t2,on='고객번호', how='left')

# %%
p = pd.merge(t1, t3,on='고객번호', how='left')

# %%
import csv
q.to_csv('대분류17기.csv',mode="w",encoding='euc-kr',index=False)

# %%
import csv
p.to_csv('대분류16기.csv',mode="w",encoding='euc-kr',index=False)

# %%
t2 = pd.read_csv('대분류16기.csv',encoding='cp949')

# %%
t2.columns
# Out:
# Index(['고객번호', '편의품구매횟수', '편의품증감1', '편의품증감2', '편의품증감3', '편의품증감4', '편의품증감5',
#        '편의품증감6', '편의품변동', '선매품구매횟수', '선매품증감1', '선매품증감2', '선매품증감3', '선매품증감4',
#        '선매품증감5', '선매품증감6', '선매품변동', '전문품구매횟수', '전문품1', '전문품2', '전문품3', '전문품4',
#        '전문품5', '전문품6', '전문품7', '기타구매횟수', '기타1', '기타2', '기타3', '기타4', '기타5',
#        '기타6', '기타7'],
#       dtype='object')

# %%
t2 = t2.drop(['기타7','전문품7'],axis=1)

# %%
t2
# Out:
#         고객번호  편의품구매횟수  편의품증감1  편의품증감2  편의품증감3  편의품증감4  편의품증감5  편의품증감6  편의품변동  \
# 0          1    691.0       2      -4       0       1       2       5     14
# 1          2    715.0       0       0       0       1      -1       2      4
# 2          3   1090.0       0      -1       1       1       0      -1      4
# 3          4    670.0      -2       4       0      -2       0       1      9
# 4          6   1090.0       0      -1       1      -1       5      -5     13
# ...      ...      ...     ...     ...     ...     ...     ...     ...    ...
# 18873  19333    638.0      -1       3       0      -2       2       0      8
# 18874  19334   1987.0      -5       0       0       3       4       2     14
# 18875  19335   1399.0      -5       0       0       1       0       2      8
# 18876  19336     41.0      -4       4       0       0       0      -1      9
# 18877  19337    962.0       0      -2       1       0      -1      -3      7
#
# ...

# %%
import csv
t2.to_csv('대분류17기.csv',mode="w",encoding='euc-kr',index=False)

# %%
t2.columns
# Out:
# Index(['고객번호', '편의품구매횟수', '편의품증감1', '편의품증감2', '편의품증감3', '편의품증감4', '편의품증감5',
#        '편의품증감6', '편의품변동', '선매품구매횟수', '선매품증감1', '선매품증감2', '선매품증감3', '선매품증감4',
#        '선매품증감5', '선매품증감6', '선매품변동', '전문품구매횟수', '전문품1', '전문품2', '전문품3', '전문품4',
#        '전문품5', '전문품6', '기타구매횟수', '기타1', '기타2', '기타3', '기타4', '기타5', '기타6'],
#       dtype='object')

# %%
t2 = t2.drop(['기타7','전문품7','전문품6','기타6','선매품증감6','편의품증감6'],axis=1)

# %%
import csv
t2.to_csv('대분류17기.csv',mode="w",encoding='euc-kr',index=False)

# %%
t2.columns
# Out:
# Index(['고객번호', '편의품구매횟수', '편의품증감1', '편의품증감2', '편의품증감3', '편의품증감4', '편의품증감5',
#        '편의품증감6', '편의품변동', '선매품구매횟수', '선매품증감1', '선매품증감2', '선매품증감3', '선매품증감4',
#        '선매품증감5', '선매품증감6', '선매품변동', '전문품구매횟수', '전문품1', '전문품2', '전문품3', '전문품4',
#        '전문품5', '전문품6', '기타구매횟수', '기타1', '기타2', '기타3', '기타4', '기타5', '기타6'],
#       dtype='object')

# %%
t3 = pd.read_csv('대분류17기.csv',encoding='cp949')

# %%
t3.columns
# Out:
# Index(['고객번호', '편의품구매횟수', '편의품증감1', '편의품증감2', '편의품증감3', '편의품증감4', '편의품증감5',
#        '편의품변동', '선매품구매횟수', '선매품증감1', '선매품증감2', '선매품증감3', '선매품증감4', '선매품증감5',
#        '선매품변동', '전문품구매횟수', '전문품1', '전문품2', '전문품3', '전문품4', '전문품5', '전문품6',
#        '기타구매횟수', '기타1', '기타2', '기타3', '기타4', '기타5', '기타6'],
#       dtype='object')

# %%
t3
# Out:
#         고객번호  편의품구매횟수  편의품증감1  편의품증감2  편의품증감3  편의품증감4  편의품증감5  편의품변동  선매품구매횟수  \
# 0          1    590.0       2      -4       0       1       2      9    268.0
# 1          2    635.0       0       0       0       1      -1      2    219.0
# 2          3    957.0       0      -1       1       1       0      3      2.0
# 3          4    559.0      -2       4       0      -2       0      8    108.0
# 4          5    578.0       1       4       3      -3       3     14     48.0
# ...      ...      ...     ...     ...     ...     ...     ...    ...      ...
# 18892  19333    577.0      -1       3       0      -2       2      8      8.0
# 18893  19334   1829.0      -5       0       0       3       4     12     39.0
# 18894  19335   1212.0      -5       0       0       1       0      6    116.0
# 18895  19336     40.0      -4       4       0       0       0      8    145.0
# 18896  19337    743.0       0      -2       1       0      -1      4      7.0
#
# ...

# %%
a = pd.read_csv('편의품테이블17기.csv',encoding='cp949')

# %%
p = pd.read_csv('선매품테이블17기.csv',encoding='cp949')

# %%
q = pd.merge(a, p,on='고객번호', how='left')

# %%
import csv
q.to_csv('편의선매대분류17.csv',mode="w",encoding='euc-kr',index=False)

# %%
b = pd.read_csv('전문품테이블17기.csv',encoding='cp949')

# %%
c = pd.read_csv('기타테이블17기.csv',encoding='cp949')

# %%
d = pd.merge(b, c,on='고객번호', how='left')

# %%
import csv
d.to_csv('전문기타대분류17.csv',mode="w",encoding='euc-kr',index=False)

# %%
e = pd.read_csv('편의품테이블16기.csv',encoding='cp949')

# %%
f = pd.read_csv('선매품테이블16기.csv',encoding='cp949')

# %%
i = pd.merge(e, f,on='고객번호', how='left')

# %%
import csv
i.to_csv('편의선매대분류16.csv',mode="w",encoding='euc-kr',index=False)

# %%
g = pd.read_csv('전문품테이블16기.csv',encoding='cp949')

# %%
h = pd.read_csv('기타테이블16기.csv',encoding='cp949')

# %%
j = pd.merge(g, h,on='고객번호', how='left')

# %%
import csv
j.to_csv('전문기타대분류16.csv',mode="w",encoding='euc-kr',index=False)
