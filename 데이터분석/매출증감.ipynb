# %%
import pandas as pd
import numpy as np
import csv
import warnings
warnings.filterwarnings('ignore')
season2 = pd.read_csv('data/동연&재호.csv')
season2
# Out:
#        Unnamed: 0   구매횟수  구매횟수.1  구매횟수.2  구매횟수.3  구매횟수.4  구매횟수.5  구매횟수.6  \
# 0               1  121.0   117.0   142.0   214.0   172.0   140.0    73.0
# 1               2  184.0   155.0   139.0   132.0   145.0   116.0   126.0
# 2               3  139.0   209.0   246.0   145.0    87.0   133.0   139.0
# 3               4   93.0   177.0    85.0    87.0   122.0   141.0   118.0
# 4               6  192.0   192.0   178.0   187.0   237.0   160.0   228.0
# ...           ...    ...     ...     ...     ...     ...     ...     ...
# 18861       19333  111.0   170.0    90.0   107.0   132.0    81.0    43.0
# 18862       19334  132.0   497.0   495.0   355.0   235.0   170.0    32.0
# 18863       19335   95.0   295.0   274.0   256.0   279.0   235.0   209.0
# 18864       19336    8.0    78.0    80.0    76.0    63.0    33.0    51.0
# 18865       19337    7.0    21.0   193.0   169.0   141.0   219.0   304.0
#
#        구매횟수.7        총구매액  ...  15_3구매경험  15_4구매경험    14년상반기금액    15년하반기금액  \
# ...

# %%
# 감소된 고객
a = season2[season2['증감확인']=='감소']

# %%
# 증가된 고객
b = season2[season2['증감확인']=='증가']

# %%
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 18861     True
# 18862     True
# 18863     True
# 18864    False
# 18865    False
# Name: 증감확인, Length: 18866, dtype: bool

# %%
a=a.drop('14년1분기금액',axis=1)

# %%
a=a.drop('15년4분기금액',axis=1)

# %%
a=a.drop('매출증감',axis=1)

# %%
a=a.drop('매출증감.1',axis=1)

# %%
a=a.drop('증감확인.1',axis=1)

# %%
a
# Out:
#        Unnamed: 0   구매횟수  구매횟수.1  구매횟수.2  구매횟수.3  구매횟수.4  구매횟수.5  구매횟수.6  \
# 0               1  121.0   117.0   142.0   214.0   172.0   140.0    73.0
# 1               2  184.0   155.0   139.0   132.0   145.0   116.0   126.0
# 2               3  139.0   209.0   246.0   145.0    87.0   133.0   139.0
# 3               4   93.0   177.0    85.0    87.0   122.0   141.0   118.0
# 8              10  462.0   412.0   390.0   444.0   469.0   449.0   454.0
# ...           ...    ...     ...     ...     ...     ...     ...     ...
# 18857       19329  140.0   253.0   142.0   185.0   196.0   149.0   170.0
# 18860       19332  215.0   608.0   337.0   346.0   304.0   391.0   412.0
# 18861       19333  111.0   170.0    90.0   107.0   132.0    81.0    43.0
# 18862       19334  132.0   497.0   495.0   355.0   235.0   170.0    32.0
# 18863       19335   95.0   295.0   274.0   256.0   279.0   235.0   209.0
#
#        구매횟수.7        총구매액  ...  14_2구매경험  14_3구매경험  14_4구매경험  15_1구매경험  \
# ...

# %%
a['14년상반기금액'].sum()
# Out:
# 101129444441.0

# %%
# 감소고객
a['Unnamed: 0'].count()
# Out:
# 9640

# %%
# 증가고객
b['Unnamed: 0'].count()
# Out:
# 9226

# %%
a['15년하반기금액'].sum()
# Out:
# 63481009603.0

# %%
b['14년상반기금액'].sum()
# Out:
# 57453205862.0

# %%
b['15년하반기금액'].sum()
# Out:
# 104291291131.0

# %%
season2['14년상반기금액'].sum()
# Out:
# 158582650303.0

# %%
season2['15년하반기금액'].sum()
# Out:
# 167772300734.0

# %%
season3 = pd.read_csv('data/3.19.csv',encoding = 'cp949')
season3
# Out:
#         고객번호  성별  연령대  거주지역  1번품목구매비율(%)  2번품목구매비율(%)  3번품목구매비율(%)  \
# 0          1   1    5     1         2.86        27.70        66.92
# 1          2   1    5     0         3.64        36.73        53.35
# 2          3   1    5     0         4.47        95.53         0.00
# 3          4   0    5     1         2.72        26.13        66.48
# 4          6   0    5     3         4.99        45.59        40.38
# ...      ...  ..  ...   ...          ...          ...          ...
# 18861  19333   0    1     0        15.53        55.08         0.00
# 18862  19334   1    2     3        13.88        66.70         0.00
# 18863  19335   0    2     0        16.72        53.31         0.00
# 18864  19336   0    2     1        10.66        30.64        54.74
# 18865  19337   1    1     1         6.46        93.54         0.00
#
#        4번품목구매비율(%)  경쟁사이용횟수  멤버쉽보유  온라인이용횟수  1기구매비율(%)  2기구매비율(%)  3기구매비율(%)  \
# 0             2.52     15.0    0.0      0.0      11.46      14.63      13.22
# ...

# %%
t= season3[['고객번호','분기증감확인']]
t
# Out:
#         고객번호  분기증감확인
# 0          1       0
# 1          2       0
# 2          3       0
# 3          4       0
# 4          6       1
# ...      ...     ...
# 18861  19333       0
# 18862  19334       0
# 18863  19335       1
# 18864  19336       1
# 18865  19337       1
#
# [18866 rows x 2 columns]

# %%
t.to_csv('sample_rere.csv')

# %%
season4= pd.read_csv('data/매출감소.csv')
season4
# Out:
#        Unnamed: 0   구매횟수  구매횟수.1  구매횟수.2  구매횟수.3  구매횟수.4  구매횟수.5  구매횟수.6  \
# 0               1  121.0   117.0   142.0   214.0   172.0   140.0    73.0
# 1               2  184.0   155.0   139.0   132.0   145.0   116.0   126.0
# 2               3  139.0   209.0   246.0   145.0    87.0   133.0   139.0
# 3               4   93.0   177.0    85.0    87.0   122.0   141.0   118.0
# 4              10  462.0   412.0   390.0   444.0   469.0   449.0   454.0
# ...           ...    ...     ...     ...     ...     ...     ...     ...
# 10625       19325   79.0    61.0    46.0     1.0   110.0   143.0   104.0
# 10626       19327  139.0   268.0   262.0   239.0   246.0   113.0    69.0
# 10627       19332  215.0   608.0   337.0   346.0   304.0   391.0   412.0
# 10628       19333  111.0   170.0    90.0   107.0   132.0    81.0    43.0
# 10629       19334  132.0   497.0   495.0   355.0   235.0   170.0    32.0
#
#        구매횟수.7        총구매액  ...  14_1구매경험  14_2구매경험  14_3구매경험  14_4구매경험  \
# ...
